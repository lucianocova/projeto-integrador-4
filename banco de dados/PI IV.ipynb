# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()

# %%
os.listdir()

# %%
arquivo_UF = r"202506Consorcios_UF\202506Consorcios_UF.csv"

# %%
df = pd.read_csv(arquivo_UF, sep=";", encoding="Latin-1")

# %%
df.head()
# Out:
#    #Data_base  CNPJ_da_Administradora  \
# 0      202506                     776
# 1      202506                     776
# 2      202506                     776
# 3      202506                     776
# 4      202506                     776
#
#                               Nome_da_Administradora  Código_do_segmento  \
# 0  ITAÚ ADM DE CONSÓRCIOS LTDA                   ...                   1
# 1  ITAÚ ADM DE CONSÓRCIOS LTDA                   ...                   2
# 2  ITAÚ ADM DE CONSÓRCIOS LTDA                   ...                   3
# 3  ITAÚ ADM DE CONSÓRCIOS LTDA                   ...                   4
# 4  ITAÚ ADM DE CONSÓRCIOS LTDA                   ...                   1
#
#   Unidade_da_Federação_do_consorciado  \
# 0                                  AC
# 1                                  AC
# 2                                  AC
# 3                                  AC
# 4                                  AL
#
# ...
